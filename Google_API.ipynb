# %% [markdown]
# ## Google Photos API - Download images from Google Photos using Python
#
# Using the Google Photos REST API you can download, upload and modify images stored in Google Photos.
#
# The following steps describe how to set up a simple project that lets you use Python to download images from Google Photos:

# %% [markdown]
# ## Create virtualenv and install required packages

# %% [markdown]
# 1. Open the terminal and navigate to your working directory. The folder structure of the repo includes the following directories:
#
#     * **credentials**: folder to store the credentials you need to authenticate your "Python App" to the Google Photos Library
#     * **media_items_list**: every time the script runs, I want to save a .csv file with all Google Photos media items and the corresponding metadata uploaded in the defined time period
#     * **downloads**: storing downloaded images from Google Photos
#
#
# 2. Create a virtual environment `python3 -m venv venv`, activate it `. ./venv/bin/activate` and install requirements `pip install -r requirements.txt`
#
# 3. Install ipykernel which provides the IPython kernel for Jupyter: `pip install ipykernel` and add your virtual environment to Jupyter: `python -m ipykernel install --user --name=venv`
#
#     You can check the installation by navigating to /Users/<user>/Library/Jupyter/kernels. There should be a new directory called 'venv'. In the folder you can find the file 'kernel.json', which contains the path for the used python installation is defined.
#
# 4. Start jupyter notebook or jupyter lab: `jupyter lab .` and select the just created environment "venv" as Kernel
#
# ![](read_me_img/select_kernel.png)

# %% [markdown]
# ## Enable Google API

# %% [markdown]
# 5. Enable Google Photos API Service
#
#    1. Go to the Google API Console [https://console.cloud.google.com/](https://console.cloud.google.com/).
#    2. From the menu bar, select a project or create a new project.
#
#       ![](read_me_img/gifs/create_new_project_speed.gif)
#
#    3. To open the Google API Library, from the Navigation menu, select APIs & Services > Library.
#    4. Search for "Google Photos Library API". Select the correct result and click "enable". If its already enabled, click "manage"
#
#        ![](read_me_img/gifs/enable_api_speed.gif)
#
#    5. Afterwards it will forward you to the "Photos API/Service details" page (https://console.cloud.google.com/apis/credentials)
#
#
# 6. Configure "OAuth consent screen" ([Source](https://stackoverflow.com/questions/65184355/error-403-access-denied-from-google-authentication-web-api-despite-google-acc))
#
#    1. Go back to the Photos API Service details page and click on "[OAuth consent screen](https://console.cloud.google.com/apis/credentials/consent)" on the left side (below "Credentials")
#    2. Add a Test user: Use the email of the account you want to use for testing the API call
#
#         ![](read_me_img/add_test_user.png)
#
# 7. Create API/OAuth credentials
#
#    1. On the left side at the Google Photos API Service page click on Credentials
#    2. Click on "Create Credentials" and create a OAuth client ID
#    3. As application type I am choosing "Desktop app" and give your client you want to use to call the API a name
#    4. Download the JSON file to the created credentials, rename it to "client_secret.json" and save it in the folder "credentials"
#
#         ![](read_me_img/gifs/create_credentials_speed.gif)

# %% [markdown]
# ## Install and import required packages

# %%
# %%capture capt 
#saves the output to variable capt, to print output capt.stdout, capt.stderr
# !pip install -r "requirements.txt"
# !pip freeze > requirements.txt

# %%
# !which python
# !which pip
# Out:
# /Users/dominikpolzer/Documents/repos/repos_test/google-photos-api/venv/bin/python
# /Users/dominikpolzer/Documents/repos/repos_test/google-photos-api/venv/bin/pip

# %% [markdown]
# ## Use the Google Photo Library API for the first time:
#
# The following section shows how to use OAuth Credentials for authentication with the Google Library API. The code section below covers the following steps:

# %% [markdown]
# 8. Create a service for the first time:
#
#     1. Initialize GooglePhotosApi `google_photos_api = GooglePhotosApi()`
#
#     2. Create Service using the `client_secret.json` file: `service = google_photos_api.create_service()`
#
#
#        <b>Calling the API for the first time:</b>
#        1. Google will ask you if you want to grant the App the required permissions you defined with the scope:
#        ![](read_me_img/sign_in_google_acc.png)
#        2. Since its just a test app at the moment, Google will make you aware of that > Click on "Continue"
#        3. Once you granted the app the required permissions, you will see a "token_......pickle" file created in the folder "credentials". This token file will be used for future calls.

# %%
import pickle
import os
from google_auth_oauthlib.flow import Flow, InstalledAppFlow
from googleapiclient.discovery import build
#from googleapiclient.http import MediaFileUpload
from google.auth.transport.requests import Request
import requests

class GooglePhotosApi:
    def __init__(self,
                 api_name = 'photoslibrary',
                 client_secret_file= r'./credentials/client_secret.json',
                 api_version = 'v1',
                 scopes = ['https://www.googleapis.com/auth/photoslibrary']):
        '''
        Args:
            client_secret_file: string, location where the requested credentials are saved
            api_version: string, the version of the service
            api_name: string, name of the api e.g."docs","photoslibrary",...
            api_version: version of the api

        Return:
            service:
        '''

        self.api_name = api_name
        self.client_secret_file = client_secret_file
        self.api_version = api_version
        self.scopes = scopes
        self.cred_pickle_file = f'./credentials/token_{self.api_name}_{self.api_version}.pickle'

        self.cred = None

    def run_local_server(self):
        # is checking if there is already a pickle file with relevant credentials
        if os.path.exists(self.cred_pickle_file):
            with open(self.cred_pickle_file, 'rb') as token:
                self.cred = pickle.load(token)

        # if there is no pickle file with stored credentials, create one using google_auth_oauthlib.flow
        if not self.cred or not self.cred.valid:
            if self.cred and self.cred.expired and self.cred.refresh_token:
                self.cred.refresh(Request())
            else:
                flow = InstalledAppFlow.from_client_secrets_file(self.client_secret_file, self.scopes)
                self.cred = flow.run_local_server()

            with open(self.cred_pickle_file, 'wb') as token:
                pickle.dump(self.cred, token)
        
        return self.cred

# %%
# initialize photos api and create service
google_photos_api = GooglePhotosApi()
creds = google_photos_api.run_local_server()

# %% [markdown]
# ### Use pythons requests module and the token file to retrieve data from Google Photos
#
# 9. Use requests python module to send http requests to the Media Items API
#
#     The following function sends a post request to the Media API to get a list of all entries. Since the API return is limited to 100 items, the search is narrowed down to one day. Thus, the call would only be a problem if more than 100 images were created/uploaded on one day.

# %%
import json
import requests

def get_response_from_medium_api(year, month, day):
    url = 'https://photoslibrary.googleapis.com/v1/mediaItems:search'
    payload = {
                  "filters": {
                    "dateFilter": {
                      "dates": [
                        {
                          "day": day,
                          "month": month,
                          "year": year
                        }
                      ]
                    }
                  }
                }
    headers = {
        'content-type': 'application/json',
        'Authorization': 'Bearer {}'.format(creds.token)
    }
    
    try:
        res = requests.request("POST", url, data=json.dumps(payload), headers=headers)
    except:
        print('Request error') 
    
    return(res)

# %% [markdown]
# Use the response of the API to write the results and required metadata into a data frame:

# %%
def list_of_media_items(year, month, day, media_items_df):
    '''
    Args:
        year, month, day: day for the filter of the API call 
        media_items_df: existing data frame with all find media items so far
    Return:
        media_items_df: media items data frame extended by the articles found for the specified tag
        items_df: media items uploaded on specified date
    '''

    items_list_df = pd.DataFrame()
    
    # create request for specified date
    response = get_response_from_medium_api(year, month, day)

    try:
        for item in response.json()['mediaItems']:
            items_df = pd.DataFrame(item)
            items_df = items_df.rename(columns={"mediaMetadata": "creationTime"})
            items_df.set_index('creationTime')
            items_df = items_df[items_df.index == 'creationTime']

            #append the existing media_items data frame
            items_list_df = pd.concat([items_list_df, items_df])
            media_items_df = pd.concat([media_items_df, items_df])
    
    except:
        print(response.text)

    return(items_list_df, media_items_df)

# %% [markdown]
# ## Use the defined functions to download media items from Google Photos
#
# 1. Create a list with all files already downloaded to the /downloads/ folder
# 2. Define a list of all dates from start date to end date (today)
# 3. Execute the API call for all dates to get a list with all media items. API returns:
#     * **id**
#     * **filename**
#     * **baseUrl**: Base URLs within the Google Photos Library API allow you to access the bytes of the media items. They are valid for 60 minutes. (https://developers.google.com/photos/library/guides/access-media-items)
#
#
# 4. Compare list of media items with files downloaded in /downloads/ with media items in Google Photos, to download items which are not downloaded yet. You can now use the baseUrl and the python requests module to send a get request for each media item.
# 5. Save a list as with all media items as .csv in /media_items_list/

# %%
import pandas as pd
from datetime import date, timedelta, datetime
import requests

# Images should only be downloaded if they are not already available in downloads
# Herefor the following code snippet, creates a list with all filenames in the /downloads/ folder
files_list = os.listdir(r'./downloads')
files_list_df = pd.DataFrame(files_list)
files_list_df = files_list_df.rename(columns={0: "filename"})
files_list_df.head(2)

# create a list with all dates between start date and today
sdate = date(2021,4,16)   # start date
edate = date.today()
date_list = pandas.date_range(sdate,edate-timedelta(days=1),freq='d')
print(date_list)

media_items_df = pd.DataFrame()

for date in date_list:
    
    # get a list with all media items for specified date (year, month, day)
    items_df, media_items_df = list_of_media_items(year = date.year, month = date.month, day = date.day, media_items_df = media_items_df)

    if len(items_df) > 0:
        # full outer join of items_df and files_list_df, the result is a list of items of the given 
        #day that have not been downloaded yet
        items_not_yet_downloaded_df = pd.merge(items_df, files_list_df,on='filename',how='left')
        items_not_yet_downloaded_df.head(2)

        # download all items in items_not_yet_downloaded
        for index, item in items_not_yet_downloaded_df.iterrows():
            url = item.baseUrl
            response = requests.get(url)

            file_name = item.filename
            destination_folder = './downloads/'

            with open(os.path.join(destination_folder, file_name), 'wb') as f:
                f.write(response.content)
                f.close()
                
        print(f'Downloaded items found for date: {date.year} / {date.month} / {date.day}')
    else:
        print(f'No media items found for date: {date.year} / {date.month} / {date.day}')
            
#save a list of all media items to a csv file
current_datetime = str(datetime.now())
filename = f'item-list-{current_datetime}.csv'

#save a list with all items in specified time frame
media_items_df.to_csv(f'./media_items_list/{filename}', index=True)
# Out:
# DatetimeIndex(['2021-04-16', '2021-04-17', '2021-04-18', '2021-04-19',
#                '2021-04-20', '2021-04-21', '2021-04-22', '2021-04-23',
#                '2021-04-24', '2021-04-25',
#                ...
#                '2022-05-02', '2022-05-03', '2022-05-04', '2022-05-05',
#                '2022-05-06', '2022-05-07', '2022-05-08', '2022-05-09',
#                '2022-05-10', '2022-05-11'],
#               dtype='datetime64[ns]', length=391, freq='D')
# {}
#
# No media items found for date: 2021 / 4 / 16
# Downloaded items found for date: 2021 / 4 / 17
# Downloaded items found for date: 2021 / 4 / 18
# Downloaded items found for date: 2021 / 4 / 19
# {}
#
# No media items found for date: 2021 / 4 / 20
# Downloaded items found for date: 2021 / 4 / 21
# Downloaded items found for date: 2021 / 4 / 22
# Downloaded items found for date: 2021 / 4 / 23
# Downloaded items found for date: 2021 / 4 / 24
# {}
#
# No media items found for date: 2021 / 4 / 25
# Downloaded items found for date: 2021 / 4 / 26
# Downloaded items found for date: 2021 / 4 / 27
# {}
#
# No media items found for date: 2021 / 4 / 28
# Downloaded items found for date: 2021 / 4 / 29
# Downloaded items found for date: 2021 / 4 / 30
# {}
#
# No media items found for date: 2021 / 5 / 1
# {}
#
# No media items found for date: 2021 / 5 / 2
# Downloaded items found for date: 2021 / 5 / 3
# Downloaded items found for date: 2021 / 5 / 4
# Downloaded items found for date: 2021 / 5 / 5
# {}
#
# No media items found for date: 2021 / 5 / 6
# {}
#
# No media items found for date: 2021 / 5 / 7
# Downloaded items found for date: 2021 / 5 / 8
# Downloaded items found for date: 2021 / 5 / 9
# Downloaded items found for date: 2021 / 5 / 10
# Downloaded items found for date: 2021 / 5 / 11
# Downloaded items found for date: 2021 / 5 / 12
# Downloaded items found for date: 2021 / 5 / 13
# Downloaded items found for date: 2021 / 5 / 14
# Downloaded items found for date: 2021 / 5 / 15
# Downloaded items found for date: 2021 / 5 / 16
# {}
#
# No media items found for date: 2021 / 5 / 17
# Downloaded items found for date: 2021 / 5 / 18
# {}
#
# No media items found for date: 2021 / 5 / 19
# Downloaded items found for date: 2021 / 5 / 20
# Downloaded items found for date: 2021 / 5 / 21
# Downloaded items found for date: 2021 / 5 / 22
# Downloaded items found for date: 2021 / 5 / 23
# Downloaded items found for date: 2021 / 5 / 24
# Downloaded items found for date: 2021 / 5 / 25
# Downloaded items found for date: 2021 / 5 / 26
# Downloaded items found for date: 2021 / 5 / 27
# Downloaded items found for date: 2021 / 5 / 28
# Downloaded items found for date: 2021 / 5 / 29
# Downloaded items found for date: 2021 / 5 / 30
# {}
#
# No media items found for date: 2021 / 5 / 31
# Downloaded items found for date: 2021 / 6 / 1
# {}
#
# No media items found for date: 2021 / 6 / 2
# Downloaded items found for date: 2021 / 6 / 3
# {}
#
# No media items found for date: 2021 / 6 / 4
# Downloaded items found for date: 2021 / 6 / 5
# Downloaded items found for date: 2021 / 6 / 6
# Downloaded items found for date: 2021 / 6 / 7
# Downloaded items found for date: 2021 / 6 / 8
# Downloaded items found for date: 2021 / 6 / 9
# Downloaded items found for date: 2021 / 6 / 10
# {}
#
# No media items found for date: 2021 / 6 / 11
# Downloaded items found for date: 2021 / 6 / 12
# {}
#
# No media items found for date: 2021 / 6 / 13
# {}
#
# No media items found for date: 2021 / 6 / 14
# Downloaded items found for date: 2021 / 6 / 15
# Downloaded items found for date: 2021 / 6 / 16
# Downloaded items found for date: 2021 / 6 / 17
# Downloaded items found for date: 2021 / 6 / 18
# Downloaded items found for date: 2021 / 6 / 19
# Downloaded items found for date: 2021 / 6 / 20
# Downloaded items found for date: 2021 / 6 / 21
# Downloaded items found for date: 2021 / 11 / 2
# Downloaded items found for date: 2021 / 11 / 3
# {}
#
# No media items found for date: 2021 / 11 / 4
# Downloaded items found for date: 2021 / 11 / 5
# Downloaded items found for date: 2021 / 11 / 6
# Downloaded items found for date: 2021 / 11 / 7
# Downloaded items found for date: 2021 / 11 / 8
# Downloaded items found for date: 2021 / 11 / 9
# {}
#
# No media items found for date: 2021 / 11 / 10
# {}
#
# No media items found for date: 2021 / 11 / 11
# {}
#
# No media items found for date: 2021 / 11 / 12
# Downloaded items found for date: 2021 / 11 / 13
# Downloaded items found for date: 2021 / 11 / 14
# {}
#
# No media items found for date: 2021 / 11 / 15
# Downloaded items found for date: 2021 / 11 / 16
# {}
#
# No media items found for date: 2021 / 11 / 17
# {}
#
# No media items found for date: 2021 / 11 / 18
# Downloaded items found for date: 2021 / 11 / 19
# Downloaded items found for date: 2021 / 11 / 20
# Downloaded items found for date: 2021 / 11 / 21
# Downloaded items found for date: 2021 / 11 / 22
# {}
#
# No media items found for date: 2021 / 11 / 23
# Downloaded items found for date: 2021 / 11 / 24
# Downloaded items found for date: 2021 / 11 / 25
# Downloaded items found for date: 2021 / 11 / 26
# Downloaded items found for date: 2021 / 11 / 27
# Downloaded items found for date: 2021 / 11 / 28
# Downloaded items found for date: 2021 / 11 / 29
# Downloaded items found for date: 2021 / 11 / 30
# {}
#
# No media items found for date: 2021 / 12 / 1
# Downloaded items found for date: 2021 / 12 / 2
# Downloaded items found for date: 2021 / 12 / 3
# {}
#
# No media items found for date: 2021 / 12 / 4
# Downloaded items found for date: 2021 / 12 / 5
# Downloaded items found for date: 2021 / 12 / 6
# {}
#
# No media items found for date: 2021 / 12 / 7
# {}
#
# No media items found for date: 2021 / 12 / 8
# {}
#
# No media items found for date: 2021 / 12 / 9
# Downloaded items found for date: 2021 / 12 / 10
# Downloaded items found for date: 2021 / 12 / 11
# {}
#
# No media items found for date: 2021 / 12 / 12
# Downloaded items found for date: 2021 / 12 / 13
# Downloaded items found for date: 2021 / 12 / 14
# Downloaded items found for date: 2021 / 12 / 15
# {}
#
# No media items found for date: 2021 / 12 / 16
# {}
#
# No media items found for date: 2021 / 12 / 17
# Downloaded items found for date: 2021 / 12 / 18
# Downloaded items found for date: 2021 / 12 / 19
# Downloaded items found for date: 2021 / 12 / 20
# {}
#
# No media items found for date: 2021 / 12 / 21
# {}
#
# No media items found for date: 2021 / 12 / 22
# {}
#
# No media items found for date: 2021 / 12 / 23
# {}
#
# No media items found for date: 2021 / 12 / 24
# {}
#
# No media items found for date: 2021 / 12 / 25
# Downloaded items found for date: 2021 / 12 / 26
# Downloaded items found for date: 2021 / 12 / 27
# Downloaded items found for date: 2021 / 12 / 28
# Downloaded items found for date: 2021 / 12 / 29
# Downloaded items found for date: 2021 / 12 / 30
# Downloaded items found for date: 2021 / 12 / 31
# Downloaded items found for date: 2022 / 1 / 1
# Downloaded items found for date: 2022 / 1 / 2
# {}
#
# No media items found for date: 2022 / 1 / 3
# {}
#
# No media items found for date: 2022 / 1 / 4
# {}
#
# No media items found for date: 2022 / 1 / 5
# Downloaded items found for date: 2022 / 1 / 6
# Downloaded items found for date: 2022 / 1 / 7
# Downloaded items found for date: 2022 / 1 / 8
# {}
#
# No media items found for date: 2022 / 1 / 9
# Downloaded items found for date: 2022 / 1 / 10
# Downloaded items found for date: 2022 / 1 / 11
# Downloaded items found for date: 2022 / 1 / 12
# Downloaded items found for date: 2022 / 1 / 13
# Downloaded items found for date: 2022 / 1 / 14
# Downloaded items found for date: 2022 / 1 / 15
# Downloaded items found for date: 2022 / 1 / 16
# Downloaded items found for date: 2022 / 1 / 17
# Downloaded items found for date: 2022 / 1 / 18
# {}
#
# No media items found for date: 2022 / 1 / 19
# {}
#
# No media items found for date: 2022 / 1 / 20
# Downloaded items found for date: 2022 / 1 / 21
# Downloaded items found for date: 2022 / 1 / 22
# Downloaded items found for date: 2022 / 1 / 23
# Downloaded items found for date: 2022 / 1 / 24
# {}
#
# No media items found for date: 2022 / 1 / 25
# {}
#
# No media items found for date: 2022 / 1 / 26
# Downloaded items found for date: 2022 / 1 / 27
# {}
#
# No media items found for date: 2022 / 1 / 28
# Downloaded items found for date: 2022 / 1 / 29
# Downloaded items found for date: 2022 / 1 / 30
# Downloaded items found for date: 2022 / 1 / 31
# Downloaded items found for date: 2022 / 2 / 1
# {}
#
# No media items found for date: 2022 / 2 / 2
# Downloaded items found for date: 2022 / 2 / 3
# Downloaded items found for date: 2022 / 2 / 4
# {}
#
# No media items found for date: 2022 / 2 / 5
# Downloaded items found for date: 2022 / 2 / 6
# Downloaded items found for date: 2022 / 2 / 7
# {}
#
# No media items found for date: 2022 / 2 / 8
# Downloaded items found for date: 2022 / 2 / 9
# Downloaded items found for date: 2022 / 2 / 10
# Downloaded items found for date: 2022 / 2 / 11
# Downloaded items found for date: 2022 / 2 / 12
# Downloaded items found for date: 2022 / 2 / 13
# {}
#
# No media items found for date: 2022 / 2 / 14
# Downloaded items found for date: 2022 / 2 / 15
# {}
#
# No media items found for date: 2022 / 2 / 16
# Downloaded items found for date: 2022 / 2 / 17
# Downloaded items found for date: 2022 / 2 / 18
# {}
#
# No media items found for date: 2022 / 2 / 19
# Downloaded items found for date: 2022 / 2 / 20
# Downloaded items found for date: 2022 / 2 / 21
# Downloaded items found for date: 2022 / 2 / 22
# Downloaded items found for date: 2022 / 2 / 23
# {}
#
# No media items found for date: 2022 / 2 / 24
# {}
#
# No media items found for date: 2022 / 2 / 25
# {}
#
# No media items found for date: 2022 / 2 / 26
# Downloaded items found for date: 2022 / 2 / 27
# {}
#
# No media items found for date: 2022 / 2 / 28
# Downloaded items found for date: 2022 / 3 / 1
# Downloaded items found for date: 2022 / 3 / 2
# {}
#
# No media items found for date: 2022 / 3 / 3
# Downloaded items found for date: 2022 / 3 / 4
# {}
#
# No media items found for date: 2022 / 3 / 5
# Downloaded items found for date: 2022 / 3 / 6
# {}
#
# No media items found for date: 2022 / 3 / 7
# Downloaded items found for date: 2022 / 3 / 8
# Downloaded items found for date: 2022 / 3 / 9
# {}
#
# No media items found for date: 2022 / 3 / 10
# Downloaded items found for date: 2022 / 3 / 11
# Downloaded items found for date: 2022 / 3 / 12
# Downloaded items found for date: 2022 / 3 / 13
# Downloaded items found for date: 2022 / 3 / 14
# {}
#
# No media items found for date: 2022 / 3 / 15
# Downloaded items found for date: 2022 / 3 / 16
# {}
#
# No media items found for date: 2022 / 3 / 17
# Downloaded items found for date: 2022 / 3 / 18
# Downloaded items found for date: 2022 / 3 / 19
# {}
#
# No media items found for date: 2022 / 3 / 20
# Downloaded items found for date: 2022 / 3 / 21
# {}
#
# No media items found for date: 2022 / 3 / 22
# {}
#
# No media items found for date: 2022 / 3 / 23
# Downloaded items found for date: 2022 / 3 / 24
# Downloaded items found for date: 2022 / 3 / 25
# Downloaded items found for date: 2022 / 3 / 26
# Downloaded items found for date: 2022 / 3 / 27
# {}
#
# No media items found for date: 2022 / 3 / 28
# Downloaded items found for date: 2022 / 3 / 29
# Downloaded items found for date: 2022 / 3 / 30
# Downloaded items found for date: 2022 / 3 / 31
# Downloaded items found for date: 2022 / 4 / 1
# Downloaded items found for date: 2022 / 4 / 2
# Downloaded items found for date: 2022 / 4 / 3
# Downloaded items found for date: 2022 / 4 / 4
# Downloaded items found for date: 2022 / 4 / 5
# Downloaded items found for date: 2022 / 4 / 6
# Downloaded items found for date: 2022 / 4 / 7
# Downloaded items found for date: 2022 / 4 / 8
# Downloaded items found for date: 2022 / 4 / 9
# Downloaded items found for date: 2022 / 4 / 10
# Downloaded items found for date: 2022 / 4 / 11
# Downloaded items found for date: 2022 / 4 / 12
# {}
#
# No media items found for date: 2022 / 4 / 13
# Downloaded items found for date: 2022 / 4 / 14
# Downloaded items found for date: 2022 / 4 / 15
# Downloaded items found for date: 2022 / 4 / 16
# Downloaded items found for date: 2022 / 4 / 17
# Downloaded items found for date: 2022 / 4 / 18
# Downloaded items found for date: 2022 / 4 / 19
# Downloaded items found for date: 2022 / 4 / 20
# Downloaded items found for date: 2022 / 4 / 21
# Downloaded items found for date: 2022 / 4 / 22
# Downloaded items found for date: 2022 / 4 / 23
# {}
#
# No media items found for date: 2022 / 4 / 24
# Downloaded items found for date: 2022 / 4 / 25
# Downloaded items found for date: 2022 / 4 / 26
# Downloaded items found for date: 2022 / 4 / 27
# Downloaded items found for date: 2022 / 4 / 28
# Downloaded items found for date: 2022 / 4 / 29
# Downloaded items found for date: 2022 / 4 / 30
# Downloaded items found for date: 2022 / 5 / 1
# Downloaded items found for date: 2022 / 5 / 2
# Downloaded items found for date: 2022 / 5 / 3
# {}
#
# No media items found for date: 2022 / 5 / 4
# {}
#
# No media items found for date: 2022 / 5 / 5
# {}
#
# No media items found for date: 2022 / 5 / 6
# {}
#
# No media items found for date: 2022 / 5 / 7
# {}
#
# No media items found for date: 2022 / 5 / 8
# {}
#
# No media items found for date: 2022 / 5 / 9
# {}
#
# No media items found for date: 2022 / 5 / 10
# {}
#
# No media items found for date: 2022 / 5 / 11

# %%
# !git add .
# !git commit -m "update jupyter notebook"
# !git push
# Out:
# Author identity unknown
#
# *** Please tell me who you are.
#
# Run
#
#   git config --global user.email "you@example.com"
#   git config --global user.name "Your Name"
#
# to set your account's default identity.
# Omit --global to set the identity only in this repository.
#
# fatal: unable to auto-detect email address (got 'dominikpolzer@Dominiks-Air.(none)')
# Everything up-to-date
